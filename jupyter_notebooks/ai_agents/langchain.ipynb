# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA
import yaml
import os

# %%
with open('config.yaml', 'r') as config:
    config = yaml.safe_load(config)
os.environ['NVIDIA_API_KEY'] = config['NVIDIA_API_KEY']

# %%
client = ChatNVIDIA(model='mistralai/mixtral-8x7b-instruct-v0.1')

# %%
result = client.invoke("Hello, who are you?")
result.content
# Out:
# "Hello! I am an assistant, a computer program that can help you with a variety of tasks. How can I assist you today?\n\nIf you have any questions about a specific topic, feel free to ask! I'll do my best to provide accurate and helpful information. If I don't know the answer, I'll let you know. You can also ask me to perform a task for you, such as setting a reminder or sending an email. Just let me know what you need!"
